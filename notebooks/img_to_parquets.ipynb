# %%
import os, json
import pandas as pd
import numpy as np
import pyarrow as pa
from PIL import Image
import pyarrow.parquet as pq
import sys
from PIL import ImageFile
ImageFile.LOAD_TRUNCATED_IMAGES = True

# %%
def filter_corrupted_images(file_paths):
    valid_images = []
    corrupted_images = []

    for path in file_paths:
        try:
            img = Image.open(path)
            img.verify()  # Verify if the image is valid
            valid_images.append(path)  # Add valid images to the list
        except (IOError, SyntaxError) as e:
            corrupted_images.append(path)  # Add corrupted images to the list
            #print(f"Corrupted image removed: {path} - {e}")

    print(f"Total corrupted images removed: {len(corrupted_images)}")
    return valid_images

# %%
import io


batch_size = 100  # Количество изображений в одном батче
image_dir = '../data/coco2017/test2017'  # Директория с изображениями
output_file = 'test2017.parquet'  # Файл, куда будут сохраняться батчи


schema = pa.schema([
    ('image_name', pa.string()),
    ('image_bin', pa.binary())
])

# Initialize the Parquet writer
writer = pq.ParquetWriter(output_file, schema)

# Функция для преобразования изображения в байтовый формат
def image_to_bytes(image_path):
    with Image.open(image_path) as img:
        img_byte_arr = io.BytesIO()
        img.save(img_byte_arr, format=img.format)  # Сохранение в байтовый поток
        return img_byte_arr.getvalue()

# Получение всех файлов изображений
image_files = [os.path.join(image_dir, fname) for fname in os.listdir(image_dir) if fname.endswith(('jpg', 'jpeg', 'png'))]

# Итерация по файлам изображений батчами
for i in range(0, len(image_files), batch_size):
    batch_files = image_files[i:i + batch_size]  # Текущий батч файлов

    batch_files = filter_corrupted_images(batch_files)    

    # Преобразование изображений в байты
    data = [image_to_bytes(path) for path in batch_files]
    
    df = pd.DataFrame(data)

    writer.write_batch(pa.RecordBatch.from_arrays([batch_files, data], names=["image_name", "image_bin"]))

writer.close()
# Out:
# Total corrupted images removed: 0
# Total corrupted images removed: 0
# Total corrupted images removed: 0
# Total corrupted images removed: 0
# Total corrupted images removed: 0
# Total corrupted images removed: 0
# Total corrupted images removed: 0
# Total corrupted images removed: 0
# Total corrupted images removed: 0
# Total corrupted images removed: 0
# Total corrupted images removed: 0
# Total corrupted images removed: 0
# Total corrupted images removed: 0
# Total corrupted images removed: 0
# Total corrupted images removed: 0
# Total corrupted images removed: 0
# Total corrupted images removed: 0
# Total corrupted images removed: 0
# Total corrupted images removed: 0
# Total corrupted images removed: 0
# Total corrupted images removed: 0
# Total corrupted images removed: 0
# Total corrupted images removed: 0
# Total corrupted images removed: 0
# Total corrupted images removed: 0
# Total corrupted images removed: 0
# Total corrupted images removed: 0
# Total corrupted images removed: 0
# Total corrupted images removed: 0
# Total corrupted images removed: 0
# Total corrupted images removed: 0
# Total corrupted images removed: 0
# Total corrupted images removed: 0
# Total corrupted images removed: 0
# Total corrupted images removed: 0
# Total corrupted images removed: 0
# Total corrupted images removed: 0
# Total corrupted images removed: 0
# Total corrupted images removed: 0
# Total corrupted images removed: 0
# Total corrupted images removed: 0
# Total corrupted images removed: 0
# Total corrupted images removed: 0
# Total corrupted images removed: 0
# Total corrupted images removed: 0
# Total corrupted images removed: 0
# Total corrupted images removed: 0
# Total corrupted images removed: 0
# Total corrupted images removed: 0
# Total corrupted images removed: 0
# Total corrupted images removed: 0
# Total corrupted images removed: 0
# Total corrupted images removed: 0
# Total corrupted images removed: 0
# Total corrupted images removed: 0
# Total corrupted images removed: 0
# Total corrupted images removed: 0
# Total corrupted images removed: 0
# Total corrupted images removed: 0
# Total corrupted images removed: 0
# Total corrupted images removed: 0
# Total corrupted images removed: 0
# Total corrupted images removed: 0
# Total corrupted images removed: 0
# Total corrupted images removed: 0
# Total corrupted images removed: 0
# Total corrupted images removed: 0
# Total corrupted images removed: 0
# Total corrupted images removed: 0
# Total corrupted images removed: 0
# Total corrupted images removed: 0
# Total corrupted images removed: 0
# Total corrupted images removed: 0
# Total corrupted images removed: 0
# Total corrupted images removed: 0
# Total corrupted images removed: 0
# Total corrupted images removed: 0
# Total corrupted images removed: 0
# Total corrupted images removed: 0
# Total corrupted images removed: 0
# Total corrupted images removed: 0
# Total corrupted images removed: 0
# Total corrupted images removed: 0
# Total corrupted images removed: 0
# Total corrupted images removed: 0
# Total corrupted images removed: 0
# Total corrupted images removed: 0
# Total corrupted images removed: 0
# Total corrupted images removed: 0
# Total corrupted images removed: 0
# Total corrupted images removed: 0
# Total corrupted images removed: 0
# Total corrupted images removed: 0
# Total corrupted images removed: 0
# Total corrupted images removed: 0
# Total corrupted images removed: 0
# Total corrupted images removed: 0
# Total corrupted images removed: 0
# Total corrupted images removed: 0
# Total corrupted images removed: 0
# Total corrupted images removed: 0
# Total corrupted images removed: 0
# Total corrupted images removed: 0
# Total corrupted images removed: 0
# Total corrupted images removed: 0
# Total corrupted images removed: 0
# Total corrupted images removed: 0
# Total corrupted images removed: 0
# Total corrupted images removed: 0
# Total corrupted images removed: 0
# Total corrupted images removed: 0
# Total corrupted images removed: 0
# Total corrupted images removed: 0
# Total corrupted images removed: 0
# Total corrupted images removed: 0
# Total corrupted images removed: 0
# Total corrupted images removed: 0
# Total corrupted images removed: 0
# Total corrupted images removed: 0
# Total corrupted images removed: 0
# Total corrupted images removed: 0
# Total corrupted images removed: 0
# Total corrupted images removed: 0
# Total corrupted images removed: 0
# Total corrupted images removed: 0
# Total corrupted images removed: 0
# Total corrupted images removed: 0
# Total corrupted images removed: 0
# Total corrupted images removed: 0
# Total corrupted images removed: 0
# Total corrupted images removed: 0
# Total corrupted images removed: 0
# Total corrupted images removed: 0
# Total corrupted images removed: 0
# Total corrupted images removed: 0
# Total corrupted images removed: 0
# Total corrupted images removed: 0
# Total corrupted images removed: 0
# Total corrupted images removed: 0
# Total corrupted images removed: 0
# Total corrupted images removed: 0
# Total corrupted images removed: 0
# Total corrupted images removed: 0
# Total corrupted images removed: 0
# Total corrupted images removed: 0
# Total corrupted images removed: 0
# Total corrupted images removed: 0
# Total corrupted images removed: 0
# Total corrupted images removed: 0
# Total corrupted images removed: 0
# Total corrupted images removed: 0
# Total corrupted images removed: 0
# Total corrupted images removed: 0
# Total corrupted images removed: 0
# Total corrupted images removed: 0
# Total corrupted images removed: 0
# Total corrupted images removed: 0
# Total corrupted images removed: 0
# Total corrupted images removed: 0
# Total corrupted images removed: 0
# Total corrupted images removed: 0
# Total corrupted images removed: 0
# Total corrupted images removed: 0
# Total corrupted images removed: 0
# Total corrupted images removed: 0
# Total corrupted images removed: 0
# Total corrupted images removed: 0
# Total corrupted images removed: 0
# Total corrupted images removed: 0
# Total corrupted images removed: 0
# Total corrupted images removed: 0
# Total corrupted images removed: 0
# Total corrupted images removed: 0
# Total corrupted images removed: 0
# Total corrupted images removed: 0
# Total corrupted images removed: 0
# Total corrupted images removed: 0
# Total corrupted images removed: 0
# Total corrupted images removed: 0
# Total corrupted images removed: 0
# Total corrupted images removed: 0
# Total corrupted images removed: 0
# Total corrupted images removed: 0
# Total corrupted images removed: 0
# Total corrupted images removed: 0
# Total corrupted images removed: 0
# Total corrupted images removed: 0
# Total corrupted images removed: 0
# Total corrupted images removed: 0
# Total corrupted images removed: 0
# Total corrupted images removed: 0
# Total corrupted images removed: 0
# Total corrupted images removed: 0
# Total corrupted images removed: 0
# Total corrupted images removed: 0
# Total corrupted images removed: 0
# Total corrupted images removed: 0
# Total corrupted images removed: 0
# Total corrupted images removed: 0
# Total corrupted images removed: 0
# Total corrupted images removed: 0
# Total corrupted images removed: 0
# Total corrupted images removed: 0
# Total corrupted images removed: 0
# Total corrupted images removed: 0
# Total corrupted images removed: 0
# Total corrupted images removed: 0
# Total corrupted images removed: 0
# Total corrupted images removed: 0
# Total corrupted images removed: 0
# Total corrupted images removed: 0
# Total corrupted images removed: 0
# Total corrupted images removed: 0
# Total corrupted images removed: 0
# Total corrupted images removed: 0
# Total corrupted images removed: 0
# Total corrupted images removed: 0
# Total corrupted images removed: 0
# Total corrupted images removed: 0
# Total corrupted images removed: 0
# Total corrupted images removed: 0
# Total corrupted images removed: 0
# Total corrupted images removed: 0
# Total corrupted images removed: 0
# Total corrupted images removed: 0
# Total corrupted images removed: 0
# Total corrupted images removed: 0
# Total corrupted images removed: 0
# Total corrupted images removed: 0
# Total corrupted images removed: 0
# Total corrupted images removed: 0
# Total corrupted images removed: 0
# Total corrupted images removed: 0
# Total corrupted images removed: 0
# Total corrupted images removed: 0
# Total corrupted images removed: 0
# Total corrupted images removed: 0
# Total corrupted images removed: 0
# Total corrupted images removed: 0
# Total corrupted images removed: 0
# Total corrupted images removed: 0
# Total corrupted images removed: 0
# Total corrupted images removed: 0
# Total corrupted images removed: 0
# Total corrupted images removed: 0
# Total corrupted images removed: 0
# Total corrupted images removed: 0
# Total corrupted images removed: 0
# Total corrupted images removed: 0
# Total corrupted images removed: 0
# Total corrupted images removed: 0
# Total corrupted images removed: 0
# Total corrupted images removed: 0
# Total corrupted images removed: 0
# Total corrupted images removed: 0
# Total corrupted images removed: 0
# Total corrupted images removed: 0
# Total corrupted images removed: 0
# Total corrupted images removed: 0
# Total corrupted images removed: 0
# Total corrupted images removed: 0
# Total corrupted images removed: 0
# Total corrupted images removed: 0
# Total corrupted images removed: 0
# Total corrupted images removed: 0
# Total corrupted images removed: 0
# Total corrupted images removed: 0
# Total corrupted images removed: 0
# Total corrupted images removed: 0
# Total corrupted images removed: 0
# Total corrupted images removed: 0
# Total corrupted images removed: 0
# Total corrupted images removed: 0
# Total corrupted images removed: 0
# Total corrupted images removed: 0
# Total corrupted images removed: 0
# Total corrupted images removed: 0
# Total corrupted images removed: 0
# Total corrupted images removed: 0
# Total corrupted images removed: 0
# Total corrupted images removed: 0
# Total corrupted images removed: 0
# Total corrupted images removed: 0
# Total corrupted images removed: 0
# Total corrupted images removed: 0
# Total corrupted images removed: 0
# Total corrupted images removed: 0
# Total corrupted images removed: 0
# Total corrupted images removed: 0
# Total corrupted images removed: 0
# Total corrupted images removed: 0
# Total corrupted images removed: 0
# Total corrupted images removed: 0
# Total corrupted images removed: 0
# Total corrupted images removed: 0
# Total corrupted images removed: 0
# Total corrupted images removed: 0
# Total corrupted images removed: 0
# Total corrupted images removed: 0
# Total corrupted images removed: 0
# Total corrupted images removed: 0
# Total corrupted images removed: 0
# Total corrupted images removed: 0
# Total corrupted images removed: 0
# Total corrupted images removed: 0
# Total corrupted images removed: 0
# Total corrupted images removed: 0
# Total corrupted images removed: 0
# Total corrupted images removed: 0
# Total corrupted images removed: 0
# Total corrupted images removed: 0
# Total corrupted images removed: 0
# Total corrupted images removed: 0
# Total corrupted images removed: 0
# Total corrupted images removed: 0
# Total corrupted images removed: 0
# Total corrupted images removed: 0
# Total corrupted images removed: 0
# Total corrupted images removed: 0
# Total corrupted images removed: 0
# Total corrupted images removed: 0
# Total corrupted images removed: 0
# Total corrupted images removed: 0
# Total corrupted images removed: 0
# Total corrupted images removed: 0
# Total corrupted images removed: 0
# Total corrupted images removed: 0
# Total corrupted images removed: 0
# Total corrupted images removed: 0
# Total corrupted images removed: 0
# Total corrupted images removed: 0
# Total corrupted images removed: 0
# Total corrupted images removed: 0
# Total corrupted images removed: 0
# Total corrupted images removed: 0
# Total corrupted images removed: 0
# Total corrupted images removed: 0
# Total corrupted images removed: 0
# Total corrupted images removed: 0
# Total corrupted images removed: 0
# Total corrupted images removed: 0
# Total corrupted images removed: 0
# Total corrupted images removed: 0
# Total corrupted images removed: 0
# Total corrupted images removed: 0
# Total corrupted images removed: 0
# Total corrupted images removed: 0
# Total corrupted images removed: 0
# Total corrupted images removed: 0
# Total corrupted images removed: 0
# Total corrupted images removed: 0
# Total corrupted images removed: 0
# Total corrupted images removed: 0
# Total corrupted images removed: 0
# Total corrupted images removed: 0
# Total corrupted images removed: 0
# Total corrupted images removed: 0
# Total corrupted images removed: 0
# Total corrupted images removed: 0
# Total corrupted images removed: 0
# Total corrupted images removed: 0
# Total corrupted images removed: 0
# Total corrupted images removed: 0
# Total corrupted images removed: 0
# Total corrupted images removed: 0
# Total corrupted images removed: 0
# Total corrupted images removed: 0
# Total corrupted images removed: 0
# Total corrupted images removed: 0
# Total corrupted images removed: 0
# Total corrupted images removed: 0
# Total corrupted images removed: 0
# Total corrupted images removed: 0
# Total corrupted images removed: 0
# Total corrupted images removed: 0
# Total corrupted images removed: 0
# Total corrupted images removed: 0
# Total corrupted images removed: 0
# Total corrupted images removed: 0
# Total corrupted images removed: 0
# Total corrupted images removed: 0
# Total corrupted images removed: 0
# Total corrupted images removed: 0
# Total corrupted images removed: 0
# Total corrupted images removed: 0
# Total corrupted images removed: 0
# Total corrupted images removed: 0
# Total corrupted images removed: 0
# Total corrupted images removed: 0
# Total corrupted images removed: 0
# Total corrupted images removed: 0
# Total corrupted images removed: 0
# Total corrupted images removed: 0
# Total corrupted images removed: 0
# Total corrupted images removed: 0
# Total corrupted images removed: 0
# Total corrupted images removed: 0
# Total corrupted images removed: 0
# Total corrupted images removed: 0
# Total corrupted images removed: 0
# Total corrupted images removed: 0
# Total corrupted images removed: 0
# Total corrupted images removed: 0
# Total corrupted images removed: 0
# Total corrupted images removed: 0
# Total corrupted images removed: 0
# Total corrupted images removed: 0

# %%
import pandas as pd

# Параметры
batch_size = 100  # Количество строк для чтения за один раз

# Функция для преобразования байтовых данных обратно в изображение
def bytes_to_image(image_bytes):
    img_byte_arr = io.BytesIO(image_bytes)
    img = Image.open(img_byte_arr)
    return img

parquet_file = pq.ParquetFile(output_file)
    
for batch in parquet_file.iter_batches(batch_size=batch_size):
    df = batch.to_pandas()
    for _, row in df.iterrows():
        image = bytes_to_image(row['image_bin'])
        image.show()  # Отобразить изображение
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# File ~/Documents/vscode_Projects/image-colorization/.venv/lib/python3.12/site-packages/PIL/ImageFile.py:547, in _save(im, fp, tile, bufsize)
#     546 try:
# --> 547     fh = fp.fileno()
#     548     fp.flush()
#
# AttributeError: '_idat' object has no attribute 'fileno'
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[15], line 19
#      17 for _, row in df.iterrows():
#      18     image = bytes_to_image(row['image_bin'])
# ---> 19     image.show()  # Отобразить изображение
#
# File ~/Documents/vscode_Projects/image-colorization/.venv/lib/python3.12/site-packages/PIL/Image.py:2623, in Image.show(self, title)
#    2603 def show(self, title: str | None = None) -> None:
#    2604     """
#    2605     Displays this image. This method is mainly intended for debugging purposes.
#    2606
#    (...)
#    2620     :param title: Optional title to use for the image window, where possible.
#    2621     """
# -> 2623     _show(self, title=title)
#
# File ~/Documents/vscode_Projects/image-colorization/.venv/lib/python3.12/site-packages/PIL/Image.py:3734, in _show(image, **options)
#    3731 def _show(image: Image, **options: Any) -> None:
#    3732     from . import ImageShow
# -> 3734     ImageShow.show(image, **options)
#
# File ~/Documents/vscode_Projects/image-colorization/.venv/lib/python3.12/site-packages/PIL/ImageShow.py:64, in show(image, title, **options)
#      55 r"""
#      56 Display a given image.
#      57
#    (...)
#      61 :returns: ``True`` if a suitable viewer was found, ``False`` otherwise.
#      62 """
#      63 for viewer in _viewers:
# ---> 64     if viewer.show(image, title=title, **options):
#      65         return True
#      66 return False
#
# File ~/Documents/vscode_Projects/image-colorization/.venv/lib/python3.12/site-packages/PIL/ImageShow.py:88, in Viewer.show(self, image, **options)
#      85     if image.mode != base:
#      86         image = image.convert(base)
# ---> 88 return self.show_image(image, **options)
#
# File ~/Documents/vscode_Projects/image-colorization/.venv/lib/python3.12/site-packages/PIL/ImageShow.py:115, in Viewer.show_image(self, image, **options)
#     113 def show_image(self, image: Image.Image, **options: Any) -> int:
#     114     """Display the given image."""
# --> 115     return self.show_file(self.save_image(image), **options)
#
# File ~/Documents/vscode_Projects/image-colorization/.venv/lib/python3.12/site-packages/PIL/ImageShow.py:111, in Viewer.save_image(self, image)
#     109 def save_image(self, image: Image.Image) -> str:
#     110     """Save to temporary file and return filename."""
# --> 111     return image._dump(format=self.get_format(image), **self.options)
#
# File ~/Documents/vscode_Projects/image-colorization/.venv/lib/python3.12/site-packages/PIL/Image.py:663, in Image._dump(self, file, format, **options)
#     661     self.im.save_ppm(filename)
#     662 else:
# --> 663     self.save(filename, format, **options)
#     665 return filename
#
# File ~/Documents/vscode_Projects/image-colorization/.venv/lib/python3.12/site-packages/PIL/Image.py:2568, in Image.save(self, fp, format, **params)
#    2565     fp = cast(IO[bytes], fp)
#    2567 try:
# -> 2568     save_handler(self, fp, filename)
#    2569 except Exception:
#    2570     if open_fp:
#
# File ~/Documents/vscode_Projects/image-colorization/.venv/lib/python3.12/site-packages/PIL/PngImagePlugin.py:1247, in _save_all(im, fp, filename)
#    1246 def _save_all(im: Image.Image, fp: IO[bytes], filename: str | bytes) -> None:
# -> 1247     _save(im, fp, filename, save_all=True)
#
# File ~/Documents/vscode_Projects/image-colorization/.venv/lib/python3.12/site-packages/PIL/PngImagePlugin.py:1431, in _save(im, fp, filename, chunk, save_all)
#    1427     im = _write_multiple_frames(
#    1428         im, fp, chunk, mode, rawmode, default_image, append_images
#    1429     )
#    1430 if im:
# -> 1431     ImageFile._save(im, _idat(fp, chunk), [("zip", (0, 0) + im.size, 0, rawmode)])
#    1433 if info:
#    1434     for info_chunk in info.chunks:
#
# File ~/Documents/vscode_Projects/image-colorization/.venv/lib/python3.12/site-packages/PIL/ImageFile.py:551, in _save(im, fp, tile, bufsize)
#     549     _encode_tile(im, fp, tile, bufsize, fh)
#     550 except (AttributeError, io.UnsupportedOperation) as exc:
# --> 551     _encode_tile(im, fp, tile, bufsize, None, exc)
#     552 if hasattr(fp, "flush"):
#     553     fp.flush()
#
# File ~/Documents/vscode_Projects/image-colorization/.venv/lib/python3.12/site-packages/PIL/ImageFile.py:570, in _encode_tile(im, fp, tile, bufsize, fh, exc)
#     567 if exc:
#     568     # compress to Python file-compatible object
#     569     while True:
# --> 570         errcode, data = encoder.encode(bufsize)[1:]
#     571         fp.write(data)
#     572         if errcode:
#
# KeyboardInterrupt:

# %%
parquet_file.metadata
# Out:
# <pyarrow._parquet.FileMetaData object at 0x11f560180>
#   created_by: parquet-cpp-arrow version 17.0.0
#   num_columns: 2
#   num_rows: 105693
#   num_row_groups: 1061
#   format_version: 2.6
#   serialized_size: 301366
